# %% [markdown]
# # Preguntas teoricas

# %% [markdown]
# ## ¿Qué es un paradigma de programación?
# Se define paradigma de programacion como un conjunto de principios y directrices que define un enfoque particular para diseñar, estructurar y escribir un código. Se divide principalmente en paradigmas imperativos y paradigmas declarativos.
# Los paradigmas imperativos tienen su código relacionado a la arquitectura de la máquina y su secuencia de pasos (instrucciones) cambian el estado delprograma. Dentro de los imperativos estan:
# -Procedimental: Enfatiza aplicar procedimientos de forma similar al funcionamiento de la máquina y se puede reutilizar el codigo.
# -Orientado a objetos: Se usa una clase, las cuales son una suerte de molde o matriz que tiene el fin de crear un objeto con atributos y funcionalidades. Tiene mayor enfasis en los datos que en los procedimientos.

# %% [markdown]
# ## ¿En qué se basa la programación orientada a objetos?
# Es un tipo de paradigma imperativo, el cual usa una clase, las cuales son una suerte de molde o matriz que tiene el fin de crear un objeto con atributos y funcionalidades. Tiene mayor enfasis en los datos que en los procedimientos. Es de los paradigmas mas utilizados debido a que es adecuado para la creacion de aplicaciones simples y complejas, se puede reutilizar el codigo, se puede incorporar fácilmente nuevas funciones al código existente y reduce los costos de produccion y mantenimiento.

# %% [markdown]
# ## ¿Cuál es la diferencia entre recursividad e iteración, y cómo se relaciona esto con la notación big 𝑂?
# La dieferencia entre recursividad e iteracion es en como se estructura el codigo, en recursividad la funcion se llama a si misma de forma directa o indirecta, en la iteracion el mismo procedimiento se repite varias veces usando bucles for o while. La notacion Big O es el lenguaje que se utiliza para ver el tiempo que tarda en ejecutarse un algoritmo, se relaciona con la recursividad e iteracion debido a que estas tienen distinto tiempo de ejecucion. iengo generalmente la iteracion mas rapida que la recursion.

# %% [markdown]
# ## explicar la diferencia de rendimiento entre 𝑂(1) y 𝑂(𝑛)
# Los algoritmos de tiempo constante O(1) ejecutan en un tiempo constante y el número de operaciones que debe realizar el algoritmo para completar una tarea determinada es independiente del tamaño de la entrada, es el algoritmo mas rapido. Los algoritmos de tiempo constante O(n) ejecutan en un tiempo lineal, crece directamente proporcional al tamaño de sus entradas, es el tercer algoritmo mas rapido.

# %% [markdown]
# ## ¿Cómo se calcula el orden en un programa que funciona por etapas?
# Para calcular el orden en un programa que funciona por etapas se debe calcular el orden de cada etapa por separado e identificar la etapa que tiene mayor orden, ese sera el orden del programa.

# %% [markdown]
# ## ¿Cómo se puede determinar la complejidad temporal de un algoritmo recursivo?
# Se pueden realizar los metodo de sustitucion, arbor de recursion y metodo maestro.
# El de sustitucion se propone una solucion y se demuestra por induccion.
# El de arbol de recursion se construye un arbol el cual cada nodo representa una recursion.
# El maestro se usa para funciones T(n) = aT(n/b) + f(n)..

# %%
import numpy as np
import matplotlib.pyplot as plt
import array

# %%
#Dos soluciones
 #las bases de esta soluciones es que para calcular la los caminos se pueden sumar los valores de los bloques de arriba y al lado 
#Solucion recursiva
class PCBrecursivo:
    def __init__(self,N,M):
        self.N = N
        self.M = M
        self.metodo = 1     
    def caminos(self,ancho,largo):
        #Caso base si solo queda un movimiento para llegar a B
        if largo == 1 or ancho == 1:
            return 1
        #No hay mas que recorrer
        if largo < 0 or ancho < 0:
            return 0
        #Aun tiene por recorrer
        else:
            return self.caminos(ancho - 1, largo) + self.caminos(ancho, largo - 1)
a = PCBrecursivo(4,5)
print("Caminos con solucion recursiva: ",a.caminos(4,5))
#Solucion iterativa
class PCBiterativo:
    def __init__(self,N,M):
      self.N = N
      self.M = M
      self.arreglo = [[0 for _ in range(M)] for _ in range(N)]
      self.metodo = 0
    def caminos(self):
       for j in range(self.M):
          self.arreglo[0][j] = 1
       for i in range(self.N):
          self.arreglo[i][0] = 1
       for i in range(1,self.N):
          for j in range(1,self.M):
             self.arreglo[i][j] = self.arreglo[i-1][j] + self.arreglo[i][j-1]
       return self.arreglo[self.N-1][self.M-1]
b = PCBiterativo(4,5)
print("Caminos con solucion iterativa",b.caminos())
# Out:
# Caminos con solucion recursiva:  35
# Caminos con solucion iterativa 35

# %%
#parte 1
import math
pcbrecursivo = []
pcbiterativo = []
#Calcular tiempo de ejecucion
from time import perf_counter
for i in range(1, 100):
    #Tiempo ejecución función pcb2
    tiempo_inicio = perf_counter()
    PCBrecursivo(50,i)
    tiempo_total = perf_counter() - tiempo_inicio
    pcbrecursivo.append(tiempo_total)
    #Tiempo ejecucion funcion pcb1
    tiempo_inicio = perf_counter()
    PCBiterativo(50,i)
    tiempo_total = perf_counter() - tiempo_inicio
    pcbiterativo.append(tiempo_total)
print("tiempo de ejecucion recursivo:", pcbrecursivo)
print("tiempo de ejecucion iterativo:", pcbiterativo)
# Out:
# tiempo de ejecucion recursivo: [6.600050255656242e-06, 1.0998919606208801e-06, 1.4998950064182281e-06, 1.200009137392044e-06, 1.00000761449337e-06, 1.00000761449337e-06, 1.00000761449337e-06, 8.00006091594696e-07, 8.998904377222061e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.998904377222061e-07, 1.00000761449337e-06, 1.6998965293169022e-06, 8.998904377222061e-07, 1.00000761449337e-06, 8.00006091594696e-07, 1.200009137392044e-06, 8.998904377222061e-07, 8.00006091594696e-07, 9.997747838497162e-07, 8.998904377222061e-07, 8.998904377222061e-07, 8.998904377222061e-07, 8.998904377222061e-07, 8.00006091594696e-07, 8.998904377222061e-07, 8.00006091594696e-07, 9.0012326836586e-07, 8.998904377222061e-07, 8.00006091594696e-07, 7.997732609510422e-07, 8.998904377222061e-07, 1.00000761449337e-06, 8.998904377222061e-07, 1.00000761449337e-06, 1.00000761449337e-06, 8.00006091594696e-07, 8.998904377222061e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.998904377222061e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.998904377222061e-07, 3.300141543149948e-06, 1.00000761449337e-06, 8.00006091594696e-07, 8.00006091594696e-07, 7.997732609510422e-07, 9.0012326836586e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 9.0012326836586e-07, 9.0012326836586e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 9.0012326836586e-07, 8.00006091594696e-07, 8.00006091594696e-07, 7.00121745467186e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.998904377222061e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.00006091594696e-07, 8.998904377222061e-07, 3.300141543149948e-06, 9.0012326836586e-07, 7.997732609510422e-07, 8.00006091594696e-07, 8.00006091594696e-07, 2.300133928656578e-06, 8.998904377222061e-07, 8.998904377222061e-07, 8.00006091594696e-07, 8.00006091594696e-07]
# tiempo de ejecucion iterativo: [2.8900103643536568e-05, 2.050003968179226e-05, 2.100015990436077e-05, 2.219993621110916e-05, 2.569984644651413e-05, 2.659996971487999e-05, 2.769986167550087e-05, 2.8799986466765404e-05, 4.3400097638368607e-05, 3.400002606213093e-05, 3.510015085339546e-05, 3.619980998337269e-05, 3.800005652010441e-05, 3.950018435716629e-05, 4.0899962186813354e-05, 4.169996827840805e-05, 5.370005965232849e-05, 4.869978874921799e-05, 4.970002919435501e-05, 5.0800153985619545e-05, 5.1900045946240425e-05, 5.279993638396263e-05, 5.3900061175227165e-05, 5.559995770454407e-05, 6.410013884305954e-05, 6.430014036595821e-05, 6.350013427436352e-05, 6.440002471208572e-05, 6.580003537237644e-05, 6.700004450976849e-05, 6.809993647038937e-05, 6.92000612616539e-05, 7.569999434053898e-05, 8.029979653656483e-05, 7.71998893469572e-05, 7.800012826919556e-05, 7.960014045238495e-05, 8.030002936720848e-05, 8.150003850460052e-05, 8.270004764199257e-05, 8.859997615218163e-05, 9.050010703504086e-05, 9.130011312663555e-05, 9.240000508725643e-05, 9.429990313947201e-05, 9.520002640783787e-05, 9.609991684556007e-05, 9.720004163682461e-05, 9.829993359744549e-05, 9.950017556548119e-05, 0.00010089995339512825, 0.00013939989730715752, 0.0001268000341951847, 0.00010779988951981068, 0.00010850001126527786, 0.0001096001360565424, 0.00011099991388618946, 0.00011220015585422516, 0.00011319993063807487, 0.0001151000615209341, 0.00011720019392669201, 0.00012199999764561653, 0.00011879997327923775, 0.00011999998241662979, 0.00014079990796744823, 0.00013619987294077873, 0.00013500009663403034, 0.00013699987903237343, 0.00014110002666711807, 0.00013689999468624592, 0.00013940013013780117, 0.0001387998927384615, 0.0001400001347064972, 0.0001414001453667879, 0.0001455999445170164, 0.000148500083014369, 0.00016289995983242989, 0.00015750015154480934, 0.0001604000572115183, 0.00015920004807412624, 0.00016229995526373386, 0.0001650999765843153, 0.00016310019418597221, 0.0001655002124607563, 0.0001650999765843153, 0.00016789999790489674, 0.00016699987463653088, 0.0001775999553501606, 0.00040929997339844704, 0.00017479993402957916, 0.00017630006186664104, 0.00017439993098378181, 0.00021359999664127827, 0.00028019980527460575, 0.0001946000847965479, 0.00019100005738437176, 0.000193099956959486, 0.0001938999630510807, 0.00019649998284876347]

# %%
plt.plot(pcbrecursivo, label=r"recursion")
plt.plot(pcbiterativo, label=r"iteracion")
plt.grid(True)
plt.xlabel('Ejecuciones')
plt.ylabel('segundos')
plt.legend()
plt.show()

# %%
#Parte 2
def tiempo(func, a, b):
    tiempo_inicio= perf_counter()
    func(a,b)
    tiempo_total = perf_counter() - tiempo_inicio
    return tiempo_total

print("tiempo que demora en ejecutar:",tiempo(PCBiterativo,1000,1000))
print("tiempo que demora en ejecutar:",tiempo(PCBrecursivo,1000,1000))
# Out:
# tiempo que demora en ejecutar: 0.08368190005421638
# tiempo que demora en ejecutar: 3.0999071896076202e-06

# %%
#Parte 3
def tiempodecorador(func):
    def tiempo1(a,b):
        tiempo_inicio = perf_counter()  
        resultado = func(a, b)  
        tiempo_total = perf_counter() - tiempo_inicio
        print("tiempo que demora en ejecutar:",tiempo_total)
        return resultado        
    return tiempo1
pcbdecoradorecursivo = tiempodecorador(PCBrecursivo) 
resultado1 = pcbdecoradorecursivo(5, 6)   

pcbdecoradoiterativo = tiempodecorador(PCBiterativo) 
resultado2 = pcbdecoradoiterativo(5, 6)
# Out:
# tiempo que demora en ejecutar: 4.200031980872154e-06
# tiempo que demora en ejecutar: 1.2699980288743973e-05

# %%
#Parte 4
#funcion para cambiar de metodo
def tiempodecorador(func):
    def tiempo1(*args,**kwargs):
        tiempo_inicio = perf_counter()  
        resultado = func(*args, **kwargs)  
        tiempo_total = perf_counter() - tiempo_inicio
        print(f"Tiempo que demora en ejecutar {func.__name__}: {tiempo_total}")
        return resultado        
    return tiempo1
class PCB:
    def __init__(self,N,M):
        self.N = N
        self.M = M
        self.arreglo = [[0 for _ in range(M)] for _ in range(N)]
        self.metodo = [0,1]
    def caminosrecursivos(self,ancho,largo):
        #Caso base si solo queda un movimiento para llegar a B
        if largo == 1 or ancho == 1:
            return 1
        #No hay mas que recorrer
        if largo < 0 or ancho < 0:
            return 0
        #Aun tiene por recorrer
        else:
            return self.caminosrecursivos(ancho - 1, largo) + self.caminosrecursivos(ancho, largo - 1)

    def caminositerativos(self):
       for j in range(self.M):
          self.arreglo[0][j] = 1
       for i in range(self.N):
          self.arreglo[i][0] = 1
       for i in range(1,self.N):
          for j in range(1,self.M):
             self.arreglo[i][j] = self.arreglo[i-1][j] + self.arreglo[i][j-1]
       return self.arreglo[self.N-1][self.M-1]


    def cambiarmetodo(self,metodo):
        if metodo == 1: 
          caminosrecursivodec = tiempodecorador(self.caminosrecursivos) 
          return caminosrecursivodec(self.N, self.M)
        elif metodo == 0:
          caminositerativosdec = tiempodecorador(self.caminositerativos)
          return caminositerativosdec()
    
pcb = PCB(9, 8)
recursivo = pcb.cambiarmetodo(1)
iterativo = pcb.cambiarmetodo(0)
print(recursivo,"caminos")
print(iterativo, "caminos")
# Out:
# Tiempo que demora en ejecutar caminosrecursivos: 0.002631699899211526
# Tiempo que demora en ejecutar caminositerativos: 2.7900096029043198e-05
# 6435 caminos
# 6435 caminos

# %%
#Parte 4
#Grafico
def tiempodecorador(func):
    def tiempo1(*args,**kwargs):
        tiempo2 = []
        for i in range(1,100):
          tiempo_inicio = perf_counter()  
          resultado = func(*args, **kwargs)  
          tiempo_total = perf_counter() - tiempo_inicio
          tiempo2.append(tiempo_total)        
        return resultado        
    return tiempo1
class PCB:
    def __init__(self,N,M):
        self.N = N
        self.M = M
        self.arreglo = [[0 for _ in range(M)] for _ in range(N)]
        self.metodo = [0,1]
    def caminosrecursivos(self,ancho,largo):
        #Caso base si solo queda un movimiento para llegar a B
        if largo == 1 or ancho == 1:
            return 1
        #No hay mas que recorrer
        if largo < 0 or ancho < 0:
            return 0
        #Aun tiene por recorrer
        else:
            return self.caminosrecursivos(ancho - 1, largo) + self.caminosrecursivos(ancho, largo - 1)

    def caminositerativos(self):
       for j in range(self.M):
          self.arreglo[0][j] = 1
       for i in range(self.N):
          self.arreglo[i][0] = 1
       for i in range(1,self.N):
          for j in range(1,self.M):
             self.arreglo[i][j] = self.arreglo[i-1][j] + self.arreglo[i][j-1]
       return self.arreglo[self.N-1][self.M-1]

    def cambiarmetodo(self,metodo):
        if metodo == 1: 
          caminosrecursivodec = tiempodecorador(self.caminosrecursivos) 
          return caminosrecursivodec(self.N, self.M)
        elif metodo == 0:
          caminositerativosdec = tiempodecorador(self.caminositerativos)
          return caminositerativosdec()
pcb = PCB(8,8)
caminosrecursivodec = tiempodecorador(pcb.caminosrecursivos)
caminositerativosdec = tiempodecorador(pcb.caminositerativos)
tiemposrecursivos= caminosrecursivodec(pcb.N, pcb.M)
tiempositerativos= caminositerativosdec()
plt.plot(tiemposrecursivos, label=r"recursion")
plt.plot(tiempositerativos, label=r"iteracion")
plt.grid(True)
plt.xlabel('Ejecuciones')
plt.ylabel('segundos')
plt.legend()
plt.show() 
#no pude solucionar el grafico :(  pero la recursion deberia estar arriba de la iteracion como salio en el grafico anterior.
